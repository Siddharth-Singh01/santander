# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
print(os.listdir("/media/shubham/$!D/santander/data/"))

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score

import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

plt.style.use('seaborn')
sns.set(font_scale=1)
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
random_state = 42
np.random.seed(random_state)
df_train = pd.read_csv('/media/shubham/$!D/santander/data/train.csv')
df_test = pd.read_csv('/media/shubham/$!D/santander/data/test.csv')

# %%
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

# %%
lgb_params = {
    "objective" : "binary",
    "metric" : "auc",
    "boosting": 'gbdt',
    "max_depth" : -1,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    "bagging_freq": 5,
    "bagging_fraction" : 0.4,
    "feature_fraction" : 0.05,
    "min_data_in_leaf": 80,
    "min_sum_heassian_in_leaf": 10,
    "tree_learner": "serial",
    "boost_from_average": "false",
    #"lambda_l1" : 5,
    #"lambda_l2" : 5,
    "bagging_seed" : random_state,
    "verbosity" : 1,
    "seed": random_state
}

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
oof = df_train[['ID_code', 'target']]
oof['predict'] = 0
predictions = df_test[['ID_code']]
val_aucs = []
feature_importance_df = pd.DataFrame()

# %%
features = [col for col in df_train.columns if col not in ['target', 'ID_code']]
X_test = df_test[features].values

# %%
for fold, (trn_idx, val_idx) in enumerate(skf.split(df_train, df_train['target'])):
    X_train, y_train = df_train.iloc[trn_idx][features], df_train.iloc[trn_idx]['target']
    X_valid, y_valid = df_train.iloc[val_idx][features], df_train.iloc[val_idx]['target']
    
    N = 5
    p_valid,yp = 0,0
    for i in range(N):
        X_t, y_t = augment(X_train.values, y_train.values)
        X_t = pd.DataFrame(X_t)
        X_t = X_t.add_prefix('var_')
    
        trn_data = lgb.Dataset(X_t, label=y_t)
        val_data = lgb.Dataset(X_valid, label=y_valid)
        evals_result = {}
        lgb_clf = lgb.train(lgb_params,
                        trn_data,
                        100000,
                        valid_sets = [trn_data, val_data],
                        early_stopping_rounds=3000,
                        verbose_eval = 1000,
                        evals_result=evals_result
                       )
        p_valid += lgb_clf.predict(X_valid)
        yp += lgb_clf.predict(X_test)
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = lgb_clf.feature_importance()
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    oof['predict'][val_idx] = p_valid/N
    val_score = roc_auc_score(y_valid, p_valid)
    val_aucs.append(val_score)
    
    predictions['fold{}'.format(fold+1)] = yp/N
# Out:
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.892958	valid_1's auc: 0.881779
# [2000]	training's auc: 0.901489	valid_1's auc: 0.88863
# [3000]	training's auc: 0.907959	valid_1's auc: 0.893272
# [4000]	training's auc: 0.912768	valid_1's auc: 0.896124
# [5000]	training's auc: 0.916485	valid_1's auc: 0.897924
# [6000]	training's auc: 0.919538	valid_1's auc: 0.898956
# [7000]	training's auc: 0.922198	valid_1's auc: 0.899582
# [8000]	training's auc: 0.924574	valid_1's auc: 0.899949
# [9000]	training's auc: 0.926847	valid_1's auc: 0.900116
# [10000]	training's auc: 0.928988	valid_1's auc: 0.900188
# [11000]	training's auc: 0.931087	valid_1's auc: 0.900279
# [12000]	training's auc: 0.933168	valid_1's auc: 0.900217
# [13000]	training's auc: 0.935196	valid_1's auc: 0.900186
# [14000]	training's auc: 0.937159	valid_1's auc: 0.900089
# Early stopping, best iteration is:
# [11127]	training's auc: 0.93136	valid_1's auc: 0.900294
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.892654	valid_1's auc: 0.881561
# [2000]	training's auc: 0.901429	valid_1's auc: 0.888689
# [3000]	training's auc: 0.90771	valid_1's auc: 0.893276
# [4000]	training's auc: 0.912429	valid_1's auc: 0.896174
# [5000]	training's auc: 0.916083	valid_1's auc: 0.898116
# [6000]	training's auc: 0.919087	valid_1's auc: 0.899161
# [7000]	training's auc: 0.921721	valid_1's auc: 0.899898
# [8000]	training's auc: 0.924158	valid_1's auc: 0.900178
# [9000]	training's auc: 0.926427	valid_1's auc: 0.90042
# [10000]	training's auc: 0.928591	valid_1's auc: 0.900491
# [11000]	training's auc: 0.930696	valid_1's auc: 0.900467
# [12000]	training's auc: 0.932763	valid_1's auc: 0.900425
# [13000]	training's auc: 0.934759	valid_1's auc: 0.900381
# Early stopping, best iteration is:
# [10562]	training's auc: 0.929775	valid_1's auc: 0.900571
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893045	valid_1's auc: 0.879733
# [2000]	training's auc: 0.902103	valid_1's auc: 0.886889
# [3000]	training's auc: 0.908624	valid_1's auc: 0.891744
# [4000]	training's auc: 0.913523	valid_1's auc: 0.895002
# [5000]	training's auc: 0.917259	valid_1's auc: 0.897219
# [6000]	training's auc: 0.920246	valid_1's auc: 0.898398
# [7000]	training's auc: 0.922849	valid_1's auc: 0.899094
# [8000]	training's auc: 0.925243	valid_1's auc: 0.899583
# [9000]	training's auc: 0.927493	valid_1's auc: 0.899907
# [10000]	training's auc: 0.92963	valid_1's auc: 0.900024
# [11000]	training's auc: 0.931713	valid_1's auc: 0.900086
# [12000]	training's auc: 0.933761	valid_1's auc: 0.900089
# [13000]	training's auc: 0.935728	valid_1's auc: 0.900118
# [14000]	training's auc: 0.937671	valid_1's auc: 0.900081
# [15000]	training's auc: 0.939617	valid_1's auc: 0.90003
# Early stopping, best iteration is:
# [12950]	training's auc: 0.935632	valid_1's auc: 0.900141
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893165	valid_1's auc: 0.879703
# [2000]	training's auc: 0.901963	valid_1's auc: 0.886921
# [3000]	training's auc: 0.908298	valid_1's auc: 0.891683
# [4000]	training's auc: 0.913069	valid_1's auc: 0.894824
# [5000]	training's auc: 0.916776	valid_1's auc: 0.896924
# [6000]	training's auc: 0.919773	valid_1's auc: 0.898213
# [7000]	training's auc: 0.92235	valid_1's auc: 0.898969
# [8000]	training's auc: 0.924725	valid_1's auc: 0.899377
# [9000]	training's auc: 0.927006	valid_1's auc: 0.899659
# [10000]	training's auc: 0.929159	valid_1's auc: 0.89997
# [11000]	training's auc: 0.931288	valid_1's auc: 0.900028
# [12000]	training's auc: 0.933373	valid_1's auc: 0.900046
# [13000]	training's auc: 0.935383	valid_1's auc: 0.900052
# [14000]	training's auc: 0.93732	valid_1's auc: 0.899956
# [15000]	training's auc: 0.939221	valid_1's auc: 0.899881
# Early stopping, best iteration is:
# [12629]	training's auc: 0.934652	valid_1's auc: 0.900096
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.89199	valid_1's auc: 0.879952
# [2000]	training's auc: 0.90081	valid_1's auc: 0.886597
# [3000]	training's auc: 0.907177	valid_1's auc: 0.89145
# [4000]	training's auc: 0.911973	valid_1's auc: 0.894838
# [5000]	training's auc: 0.915661	valid_1's auc: 0.896756
# [6000]	training's auc: 0.918701	valid_1's auc: 0.898179
# [7000]	training's auc: 0.921325	valid_1's auc: 0.899087
# [8000]	training's auc: 0.923734	valid_1's auc: 0.899513
# [9000]	training's auc: 0.926017	valid_1's auc: 0.899795
# [10000]	training's auc: 0.928224	valid_1's auc: 0.899988
# [11000]	training's auc: 0.930382	valid_1's auc: 0.900001
# [12000]	training's auc: 0.932448	valid_1's auc: 0.90006
# [13000]	training's auc: 0.934508	valid_1's auc: 0.899962
# [14000]	training's auc: 0.936525	valid_1's auc: 0.899954
# [15000]	training's auc: 0.938506	valid_1's auc: 0.899892
# Early stopping, best iteration is:
# [12029]	training's auc: 0.93251	valid_1's auc: 0.900073
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.892648	valid_1's auc: 0.879661
# [2000]	training's auc: 0.901289	valid_1's auc: 0.886783
# [3000]	training's auc: 0.907574	valid_1's auc: 0.891658
# [4000]	training's auc: 0.912333	valid_1's auc: 0.894878
# [5000]	training's auc: 0.916073	valid_1's auc: 0.896973
# [6000]	training's auc: 0.919091	valid_1's auc: 0.898058
# [7000]	training's auc: 0.921735	valid_1's auc: 0.898849
# [8000]	training's auc: 0.924174	valid_1's auc: 0.899458
# [9000]	training's auc: 0.926442	valid_1's auc: 0.899778
# [10000]	training's auc: 0.92864	valid_1's auc: 0.89999
# [11000]	training's auc: 0.930789	valid_1's auc: 0.900038
# [12000]	training's auc: 0.932844	valid_1's auc: 0.900108
# [13000]	training's auc: 0.934862	valid_1's auc: 0.900087
# [14000]	training's auc: 0.936797	valid_1's auc: 0.900085
# [15000]	training's auc: 0.93875	valid_1's auc: 0.900143
# [16000]	training's auc: 0.940677	valid_1's auc: 0.900049
# [17000]	training's auc: 0.942543	valid_1's auc: 0.900003
# Early stopping, best iteration is:
# [14959]	training's auc: 0.938669	valid_1's auc: 0.90016
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893017	valid_1's auc: 0.877343
# [2000]	training's auc: 0.901714	valid_1's auc: 0.884708
# [3000]	training's auc: 0.907938	valid_1's auc: 0.889642
# [4000]	training's auc: 0.912736	valid_1's auc: 0.892833
# [5000]	training's auc: 0.916492	valid_1's auc: 0.894877
# [6000]	training's auc: 0.919475	valid_1's auc: 0.896073
# [7000]	training's auc: 0.922088	valid_1's auc: 0.896633
# [8000]	training's auc: 0.924505	valid_1's auc: 0.896994
# [9000]	training's auc: 0.926746	valid_1's auc: 0.897069
# [10000]	training's auc: 0.928888	valid_1's auc: 0.897188
# [11000]	training's auc: 0.930991	valid_1's auc: 0.897195
# [12000]	training's auc: 0.932998	valid_1's auc: 0.897147
# [13000]	training's auc: 0.935	valid_1's auc: 0.896987
# Early stopping, best iteration is:
# [10673]	training's auc: 0.9303	valid_1's auc: 0.897268
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893193	valid_1's auc: 0.877241
# [2000]	training's auc: 0.901862	valid_1's auc: 0.884531
# [3000]	training's auc: 0.908111	valid_1's auc: 0.889467
# [4000]	training's auc: 0.91295	valid_1's auc: 0.892685
# [5000]	training's auc: 0.916711	valid_1's auc: 0.894769
# [6000]	training's auc: 0.919757	valid_1's auc: 0.895991
# [7000]	training's auc: 0.922363	valid_1's auc: 0.896684
# [8000]	training's auc: 0.924772	valid_1's auc: 0.897172
# [9000]	training's auc: 0.927057	valid_1's auc: 0.897317
# [10000]	training's auc: 0.929223	valid_1's auc: 0.897331
# [11000]	training's auc: 0.931324	valid_1's auc: 0.897391
# [12000]	training's auc: 0.933385	valid_1's auc: 0.89741
# [13000]	training's auc: 0.935365	valid_1's auc: 0.897403
# [14000]	training's auc: 0.937326	valid_1's auc: 0.897308
# Early stopping, best iteration is:
# [11550]	training's auc: 0.93247	valid_1's auc: 0.897463
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893393	valid_1's auc: 0.877277
# [2000]	training's auc: 0.90202	valid_1's auc: 0.884646
# [3000]	training's auc: 0.908384	valid_1's auc: 0.88931
# [4000]	training's auc: 0.913133	valid_1's auc: 0.892436
# [5000]	training's auc: 0.916858	valid_1's auc: 0.894519
# [6000]	training's auc: 0.919842	valid_1's auc: 0.895791
# [7000]	training's auc: 0.922482	valid_1's auc: 0.896343
# [8000]	training's auc: 0.92491	valid_1's auc: 0.896799
# [9000]	training's auc: 0.9272	valid_1's auc: 0.897018
# [10000]	training's auc: 0.929401	valid_1's auc: 0.897128
# [11000]	training's auc: 0.931505	valid_1's auc: 0.897161
# [12000]	training's auc: 0.933577	valid_1's auc: 0.897132
# [13000]	training's auc: 0.935581	valid_1's auc: 0.897147
# [14000]	training's auc: 0.937555	valid_1's auc: 0.897007
# Early stopping, best iteration is:
# [11394]	training's auc: 0.932334	valid_1's auc: 0.897236
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893696	valid_1's auc: 0.877122
# [2000]	training's auc: 0.902132	valid_1's auc: 0.884431
# [3000]	training's auc: 0.908421	valid_1's auc: 0.889389
# [4000]	training's auc: 0.913116	valid_1's auc: 0.892541
# [5000]	training's auc: 0.916833	valid_1's auc: 0.89456
# [6000]	training's auc: 0.919839	valid_1's auc: 0.895941
# [7000]	training's auc: 0.922473	valid_1's auc: 0.896625
# [8000]	training's auc: 0.924895	valid_1's auc: 0.89705
# [9000]	training's auc: 0.92717	valid_1's auc: 0.897249
# [10000]	training's auc: 0.929307	valid_1's auc: 0.897223
# [11000]	training's auc: 0.931375	valid_1's auc: 0.897339
# [12000]	training's auc: 0.93342	valid_1's auc: 0.897252
# [13000]	training's auc: 0.93539	valid_1's auc: 0.897103
# [14000]	training's auc: 0.937369	valid_1's auc: 0.897024
# Early stopping, best iteration is:
# [11122]	training's auc: 0.931621	valid_1's auc: 0.89736
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.894181	valid_1's auc: 0.877107
# [2000]	training's auc: 0.902859	valid_1's auc: 0.8845
# [3000]	training's auc: 0.909112	valid_1's auc: 0.889476
# [4000]	training's auc: 0.913872	valid_1's auc: 0.89266
# [5000]	training's auc: 0.917597	valid_1's auc: 0.894803
# [6000]	training's auc: 0.920565	valid_1's auc: 0.896127
# [7000]	training's auc: 0.923204	valid_1's auc: 0.896753
# [8000]	training's auc: 0.92561	valid_1's auc: 0.897267
# [9000]	training's auc: 0.927842	valid_1's auc: 0.897355
# [10000]	training's auc: 0.929973	valid_1's auc: 0.897427
# [11000]	training's auc: 0.932034	valid_1's auc: 0.89742
# [12000]	training's auc: 0.934092	valid_1's auc: 0.897435
# [13000]	training's auc: 0.936067	valid_1's auc: 0.897396
# [14000]	training's auc: 0.938028	valid_1's auc: 0.897353
# Early stopping, best iteration is:
# [11574]	training's auc: 0.933227	valid_1's auc: 0.897485

# %%
mean_auc = np.mean(val_aucs)
std_auc = np.std(val_aucs)
all_auc = roc_auc_score(oof['target'], oof['predict'])
print("Mean auc: %.9f, std: %.9f. All auc: %.9f." % (mean_auc, std_auc, all_auc))
# Out:
# Mean auc: 0.901663554, std: 0.003045511. All auc: 0.901618498.

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)
best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (averaged over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
# submission
predictions['target'] = np.mean(predictions[[col for col in predictions.columns if col not in ['ID_code', 'target']]].values, axis=1)
predictions.to_csv('lgb_all_predictions.csv', index=None)
sub_df = pd.DataFrame({"ID_code":df_test["ID_code"].values})
sub_df["target"] = predictions['target']
sub_df.to_csv("lgb_submission.csv", index=False)
oof.to_csv('lgb_oof.csv', index=False)
